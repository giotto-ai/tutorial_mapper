# %% [markdown]
# ## Load libraries

# %%
# uncomment to install 3D plotting library
# pip install PyGEL3D

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from PyGEL3D import gel
from PyGEL3D import js

import plotly.graph_objects as go

import numpy as np

import sys; sys.path.append("../giotto-learn/") # <--- TMP!!!
from giotto.mapper import *
from giotto.mapper.visualize import create_interactive_network

from sklearn.cluster import DBSCAN, KMeans

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load image

# %%
m = gel.obj_load("alien.obj")

# %% [markdown]
# ## Plot image

# %%
# plot image and color by height
pos = m.positions()
js.display(m, data=pos[:,2], wireframe=True)
# Out:
# FigureWidget({
#     'data': [{'color': '#dddddd',
#               'flatshading': False,
#               'i': array(…

# %% [markdown]
# ## Downsample image

# %%
n_samples = 1000 
indices = np.random.choice(pos.shape[0], n_samples, replace=False)

# %%
sample = pos[indices]

# %%
x, y, z = sample[:, 0], sample[:, 1], sample[:, 2]

fig = go.Figure(data=[go.Scatter3d(x=x, y=y, z=z, mode='markers', marker=dict(size=1))])
fig.show()
# Out:
# <div>
#
#
#             <div id="2524d51f-289d-4549-99bc-fda4770b73f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2524d51f-289d-4549-99bc-fda4770b73f0")) {
#                     Plotly.newPlot(
#                         '2524d51f-289d-4549-99bc-fda4770b73f0',
#                         [{"marker": {"size": 1}, "mode": "markers", "type": "scatter3d", "x": [1.8775, -9.6259, 4.1764, -54.2925, -7.9219, 26.2478, 49.1916, 56.1034, 12.8802, 7.8113, -10.5295, 52.6046, -2.5034, 59.5236, 2.8579, -1.8228, 11.6824, -6.9346, 5.7857, 0.0023, -2.4597, 21.4614, -8.2587, -1.5393, -5.8372, -6.9941, 32.4501, 7.6619, 11.1377, 54.7594, 56.6152, -0.4044, 55.1584, 13.4784, 53.7639, 9.6777, 11.5262, -60.2652, 7.4646, -58.7182, -52.1938, -50.0143, -39.4578, -9.4231, 8.4238, -6.0038, 60.2993, -57.8184, 58.647, -4.2625, -3.8646, -58.6608, -57.418, -23.8335, 58.452, 11.5639, 52.3834, -48.7152, 6.3274, 1.9055, 56.4647, -8.25, -5.254, -9.0796, 56.8589, 39.8521, 56.722, -4.2457, -9.8009, -58.999, -51.4412, -57.7084, 4.2906, 2.7435, 6.2036, 58.7249, 8.3899, -10.2272, -8.3459, 36.2162, 10.4867, -1.2155, -50.6382, -6.6577, 57.5514, -58.8892, 2.3355, 59.5421, -5.3096, 10.1784, 54.2925, -3.6989, -37.8569, -3.1618, 57.4619, 1.6116, 0.0092, 5.3051, 2.7411, 7.7285, 59.81, 5.7241, 59.6175, -8.5039, -3.4881, -58.0527, -2.539, 51.8858, 8.961, -48.9424, -58.3557, 57.2382, -5.2932, -50.0743, 32.3239, 3.764, 16.1297, -50.0562, 1.0638, -55.5307, 2.6352, -6.1492, 33.825, -0.2073, -0.6428, -8.9129, 51.2692, -0.5069, 59.6734, 1.7068, -7.6219, -11.6805, -8.3384, 13.45, 7.5197, 37.1593, -1.7237, 4.6788, 2.5894, 59.1908, 49.4272, 7
.5304, 9.5523, 7.7362, 60.2301, -52.0772, -6.978, 6.454, 2.4664, -1.4646, -6.4236, 0.4002, -10.8867, 57.7824, 2.5254, -55.1275, -0.5379, 56.0539, -5.1173, -58.8906, -0.6065, 52.4627, 58.6402, 35.1653, 55.4972, -14.0418, 0.0, -10.9901, 50.5821, 58.775, -51.976, 5.75, 3.1265, -35.6866, -10.1717, -57.3451, -6.9128, -56.1706, -0.9955, 3.7389, -5.2217, 0.5541, 12.9351, -8.1187, -9.012, -5.8129, -51.3706, 11.5676, 4.6 ...

# %% [markdown]
# ## Rescale to unit height

# %%
z_max, z_min = np.max(sample[:, 2]), np.min(sample[:, 2])

# %%
scale = z_max - z_min

# %%
z_scaled = (z - z_min) / (z_max - z_min)

# %%
x_scaled, y_scaled = x / scale, y / scale

# %%
fig = go.Figure(data=[go.Scatter3d(x=x_scaled, y=y_scaled, z=z_scaled, mode='markers', marker=dict(size=1))])
fig.show()
# Out:
# <div>
#
#
#             <div id="9622a2e8-28db-4f35-afcb-c8cb68ffd702" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9622a2e8-28db-4f35-afcb-c8cb68ffd702")) {
#                     Plotly.newPlot(
#                         '9622a2e8-28db-4f35-afcb-c8cb68ffd702',
#                         [{"marker": {"size": 1}, "mode": "markers", "type": "scatter3d", "x": [0.013938536806274755, -0.0714625626862957, 0.031005542006778103, -0.4030668492967628, -0.05881208773668601, 0.19486334294739735, 0.3651978307108097, 0.4165109485257817, 0.09562244568425039, 0.05799099470298482, -0.07817087792365914, 0.3905359005482615, -0.01858521067420944, 0.44190247107428815, 0.021217014294888214, -0.013532444682012049, 0.08672999328129118, -0.051482384733311806, 0.0429529653262657, 1.707517158691448e-05, -0.018260782414058065, 0.15932916847626366, -0.061312486776022, -0.011427744184233677, -0.043335300690059655, -0.05192411199827764, 0.2409091415271885, 0.05688185094860002, 0.08268614721025105, 0.40653310912890644, 0.42031054540325247, -0.0030022606042383543, 0.40949528019985376, 0.10006347509437745, 0.39914252942683104, 0.07184712524638359, 0.08557036641091029, -0.4474081003129211, 0.05541709818594862, -0.43592319142380953, -0.38748612642308566, -0.37130554534757254, -0.2929342197574583, -0.06995697799158862, 0.0625381871364566, -0.04457213703196398, 0.44766125829166625, -0.42924308733950267, 0.4353946035033798, -0.03164474734314043, -0.028690742658604215, -0.4354970545329013, -0.42627052268585025, -0.1769396095724897, 0.43394692591231526, 0.08585025074518277, 0.38889371448085913, -0.3616610429960245, 0.04697453943436638, 0.014146408460376321, 0.41919323526245655, -0.06124789808349759, -0.03900563109462986, -0.06740683823502118, 0.4221197711927007, 0.29586149808646717, 0.42110342728389705, -0.031520024350679486, -0.0727617605244305, -0.43800784715494234, -0.38189883332034136, -0.42842644869838936, 0.03185336139600664, 0.02036771010813038, 0.04605544976373159, 0.43597293214104094, 0.062286513955240784, -0.07592660645812685, -0.06195985849879546, 0.26886862140261397, 0.0778531312523896, -0.009023856984301979, -0.37593737124021426, -0.049426682554000234, 0.4272608826378913, -0.43719269331135835, 0.017338723148364682, 0.4420398148457481, -0.0394184048077744, 0.0755643158609784, 0.4030668492967628, -0.027460587905581726, -0.2810491579342012, -0.02347316414065487, 0.42659643574353096, 0.011964498491074511, 6.830068634765791e-05, 0.039384996863365225, 0.020349892537778816, 0.0573762885258559, 0.4440287011362413, 0.04249564768724225, 0.44259958351429307, -0.06313284854694001, -0.025895611309702783, -0.430982527645074, -0.01884950463442429, 0.38519953822796843, 0.06652635330014811, -0.36334777298930576, -0.4332319959019588, 0.42493568970701234, -0.03929665141037205, -0.37175098460636163, 0.23997223428620218, 0.02794388950136787, 0.11974669354150194, -0.37161661042996025, 0.007897638058330271, -0.41225923080064, 0.019563692246016104, -0.045651584835762836, 0.25111638214234017, -0.0015389926391162487, -0.004772139259160273, -0.0661692594943522, 0.380621907445146, -0.0037632193380030218, 0.44301458442373154, 0.012671262115019842, -0.05658489144274064, -0.08671588770476286, -0.061904178591446826, 0.09985263384521728, 0.05582615990526992, 0.2758701841520136, -0.01279672750624543, 0.03473535340037194, 0.01922367361180711, 0.4394317679855381, 0.3669469222003215, 0.05572816326833632, 0.3566305489667665, -0.43662921264899013, -0.024789437150376584, -0.06490569679692053, 0.07321165417580745, 0.007608102540117373, 0.023266034885317952, -0.4116304190469827, 0.060685902218658716, 0.4425825083427061, -0.4324992483212508, -0.06335408337880526, -0.0019718111189062984, 0.008991933837422096, 0.4183654606398735, -0.06844990849935226, -0.059364432417584455, 0.2523257497299525, -0.030171828194077883, 0.07778928495862983, -0.006824871843413253, 0.3754392216691352, -0.3827941662305074, 0.03665965099834074, -0.019467180406611804, 0.42014870247255914, -0.3792106073935493, 0.4313953013582186, -0.016985341336392016, 0.11120316855792751, -0.01548792302809608, 0.07748193187006537, 0.013458947204311853, -0.43143910288533277, -0.006265845573632966, 0.10608284427814711, -0.26224642442194973, 0.07959999554560741, 0.05267838914316047, -0.04391734132154405 ...

# %% [markdown]
# ## Mapper
#
# The one-dimensional projection does not seem to reveal the desired structure, so project onto x- and z-axis.

# %%
X = np.vstack([x_scaled, y_scaled, z_scaled]).T

# %%
X.shape
# Out:
# (1000, 3)

# %%
# define filter function - can be any scikit-learn Transformer
filter_func = Projection(column_indices=[0,2])
# define cover - only one type is available at the moment
cover = CubicalCover(n_intervals=10, overlap_frac=0.3)
# choose clustering algorithm - default is DBSCAN
clusterer = FirstSimpleGap(linkage='single')

# %%
# initialise pipeline
n_jobs_outer = 1

pipe = make_mapper_pipeline(filter_func=filter_func,
                            cover=cover,
                            clusterer=clusterer,
                            verbose=False,
                            n_jobs_outer=n_jobs_outer)

# %%
graph = pipe.fit_transform(X)

# %%
# OK params: overlap_frac = 0.4 and relative_gap = 0.8
create_interactive_network(pipe, X)
# Out:
# VBox(children=(HBox(children=(IntSlider(value=10, description='n_intervals', max=50, min=1), FloatSlider(value…
# Output()
